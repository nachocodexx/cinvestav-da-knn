# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
# plt.scatter(X_CIRCLE_test[:,0],X_CIRCLE_test[:,1],color="black",alpha=.5)

# %%
df = pd.read_csv('data.csv',delimiter='\t',header=None)
X  = df.values
#  TOTAL DE CLASES 
C  = 3
# TOTAL DE PATRONES EN EL CONJUNTO
N  = X.shape[0]*C
# TOTAL DE DIMENENSIONES
D  = X.shape[1]//3

# %%
w0       = X[:,:3]
w0_class = np.repeat(0,w0.shape[0]).reshape(-1,1)
w0       = np.hstack([w0,w0_class])

w1       = X[:,3:6]
w1_class = np.repeat(1,w0.shape[0]).reshape(-1,1)
w1       = np.hstack([w1,w1_class])

w2       = X[:,6:]
w2_class = np.repeat(2,w0.shape[0]).reshape(-1,1)
w2       = np.hstack([w2,w2_class])
__X      = np.vstack([w0,w1,w2])

# %%
# %matplotlib notebook
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')
ax.scatter(w0[:,0],w0[:,1],w0[:,2],color="black",s=100,alpha=1)
ax.scatter(w1[:,0],w1[:,1],w1[:,2],color="red",s=100,alpha=1)
ax.scatter(w2[:,0],w2[:,1],w2[:,2],color="blue",s=100,alpha=1)
# Out:
# <img src="data:image/png;base64,..." width="323.33334189874176">

# %%
def knn_relative_px(X,**kwargs):
    k       = kwargs.get('k',1)
    xt      = kwargs.get('xt')
    q       = kwargs.get('q',2)
    counter = knn_classifier(X,k=k,get_counter=True,q=q)(xt)
    values  = list(counter.values())
    klass   = np.argmax(values)
    for i,cx in enumerate(values):
        print("K={}".format(k),"P( w{} | {})=".format(i,xt),cx/k)
    print("El patrón {} pertenece a la clase w{}".format(xt,klass))
        
#     return k/(n*V)

def knn_pwj_xt(**kwargs):
    ki = kwargs.get('ki',1)
    k  = kwargs.get('k',1)
    return ki/k

def knn_classifier(X,**kwargs):
    k           = kwargs.get('k',1)
    get_results = kwargs.get('get_radio',False)
    get_counter = kwargs.get('get_counter',False)
    # q is the parameter for the Lq, when q = 2 it represents the Euclidean distance, q=2 is the default value     
    q           = kwargs.get('q',2)
    # D is a constant that represent the number of dimensions
#     center   = kwargs.get('xt',np.zeros(D))
    dtype    = [('distance',float),('class',int)] 
    def __knn_classifier(center):
        result   = list(map(__fn(center,q=q),X ))
        result   = np.array(result,dtype = dtype)
        knearest = np.sort(result,order='distance')
        knearest = knearest[:k]
        keys     = list(map(lambda i:(i,0) ,range(c)  ))
        counter  = dict(keys) 
        for (distance,klass) in knearest:
            counter[klass]+=1
        if get_results:
            return knearest[-1][1]
        elif get_counter:
            return counter
        else:
            return np.argmax(list(counter.values()))
    return __knn_classifier
def knn_classifierS(X,**kwargs):
    k      = kwargs.get('k',1)
    q      = kwargs.get('q',2)
    XT     = kwargs.get('XT')
    get_radios = kwargs.get('get_radio',False)
    result = []
    for xt in XT:
        result.append(knn_classifier(X,k=k,get_radio=get_radios,q=q)(xt))
    return np.array(result)
    

def __fn(center,**kwargs):
    q              = kwargs.get('q',2)
    def _fn(xt):
        xi    = xt[:3]
        klass = int(xt[-1])
        distance_val = Lq(center,q=q)(xi.reshape(1,xi.shape[0]))[0]
        return (distance_val,klass)
    return _fn

# knn_relative_px(__X,xt = w0[],k=1)
# knn_classifierS(__X,XT=w2[:,:3],k=1,q=2)
# knn_classifier(__X,k=1)
# (w2[9,:3])
# w0[:,:3]
# __X

# %% [markdown]
# # Práctica #1
# Considere las estimaciones de densidad usando los k-vecinos más cercanos (kNN) en diferente número de dimensiones. Se utilizarán los datos mostrados en la Tabla 1.

# %% [markdown]
# a) Escriba un programa para la estimación de densidad kNN de n puntos en d dimensiones, de acuerdo con la Ecuación 15, de la clase AD-05.

# %% [markdown]
# $p(x) = \frac{k}{nV}$

# %%
def knn_px_est(**kwargs):
    # k is the number of the nearest datapoints.
    k = kwargs.get('k',1)
    # N is a constant that represents the total number of patterns in the training set.
    n = kwargs.get('n',N)
#     V = kwargs.get('V',1)
    return lambda V: k/(n*V)

# %% [markdown]
# $V = V_0 \cdot r^{d}$
#
# $
# V_0 =
# \begin{cases}
# \pi^{d/2} / (d/2)!, & \text{si }d\text{ es par} \\
# 2^{d} \pi^{d-1}/2 (\frac{d-1}{2}!) / d!, & \text{si }d\text{ es impar}
# \end{cases}
# $

# %%
def knn_V(r,**kwargs):
    __factorial = np.math.factorial
    # D is a constant that represent the number of dimensions
    d   = kwargs.get('d',D)
    fn1 = np.power(np.pi,d//2)/__factorial(d//2)
    
    fn2 = (np.power(2,d) * np.power(np.pi,(d-1)//2)*__factorial((d-1)//2))/__factorial(d)
    Vo  = fn1 if(d%2 ==0) else fn2
    return Vo*np.power(r,d)

# %% [markdown]
# b) Use su programa para $k = [1, 3, 5, 7]$ para estimar la densidad relativa en los siguientes puntos para cada una de las clases $\omega_i$, $i = 1, 2, 3$: $(−0.41, 0.82, 0.88)^T$,$(0.14,0.72, 4.1)^T$, y $(−0.81, 0.61, −0.38)^T$.Utilice la regla de máxima probabilidad para clasificar estos puntos (Clase AD-05, Ecuación 14).

# %%
patterns = np.array([ [-.41,.82,.88],[.14,.72,4.1],[-.81,.61,-.38] ])
ks=[1,3,5,7]
# ks=[1]
for xt in patterns:
    for k in ks:
        knn_relative_px(__X,xt=xt,k=k,q=2)
        print("_"*100)
    print("*"*100)
# Out:
# K=1 P( w0 | [-0.41  0.82  0.88])= 0.0
# K=1 P( w1 | [-0.41  0.82  0.88])= 1.0
# K=1 P( w2 | [-0.41  0.82  0.88])= 0.0
# El patrón [-0.41  0.82  0.88] pertenece a la clase w1
# ____________________________________________________________________________________________________
# K=3 P( w0 | [-0.41  0.82  0.88])= 0.0
# K=3 P( w1 | [-0.41  0.82  0.88])= 1.0
# K=3 P( w2 | [-0.41  0.82  0.88])= 0.0
# El patrón [-0.41  0.82  0.88] pertenece a la clase w1
# ____________________________________________________________________________________________________
# K=5 P( w0 | [-0.41  0.82  0.88])= 0.0
# K=5 P( w1 | [-0.41  0.82  0.88])= 0.6
# K=5 P( w2 | [-0.41  0.82  0.88])= 0.4
# El patrón [-0.41  0.82  0.88] pertenece a la clase w1
# ____________________________________________________________________________________________________
# K=7 P( w0 | [-0.41  0.82  0.88])= 0.0
# K=7 P( w1 | [-0.41  0.82  0.88])= 0.5714285714285714
# K=7 P( w2 | [-0.41  0.82  0.88])= 0.42857142857142855
# ...

# %% [markdown]
# ## Práctica #2
# Explore el efecto de la medición de distancia del clasificador 1NN al utilizar diferentes valores de q en la norma $L_q$ o métrica Minkowski:

# %%
def Lq(a,**kwargs):
    q = kwargs.get('q',1)
    npower = np.power
    return lambda b: npower( npower(np.abs(a-b),q).sum(axis=1) ,1/q )

# %% [markdown]
# a) Escriba un programa que implemente el clasificador 1NN para $c$ clases, usando la norma $L_q$, donde $q$ puede variarse.

# %%
oneKnn = lambda q : knn_classifier(__X, k=1,q=q)

# %% [markdown]
# b) Use las muestras tridimensionales de la Tabla 1 para clasificar los siguientes puntos usando la norma $L_q$ para $q =$ $(1/2, 1, 2, \infty)$: $(2.21, 1.9, 0.43)^T$,$(−0.5, 1.17, 6.19)^T$
# , y $(0.01, 1.34, 2.60)^T$.

# %%
qs       = [0.5,1,2,np.inf]
patterns = np.array([[2.21,1.9,0.43],[-.5,1.17,6.19],[0.01,1.34,2.60]])
for xt in patterns:
    for q in qs:
        klass = oneKnn(q)(xt)
        print("q= {},\tEl patrón {} pertence a la clase w{}".format(q,xt,klass))
    print("*"*100)
# Out:
# q= 0.5,	El patrón [2.21 1.9  0.43] pertence a la clase w0
# q= 1,	El patrón [2.21 1.9  0.43] pertence a la clase w0
# q= 2,	El patrón [2.21 1.9  0.43] pertence a la clase w0
# q= inf,	El patrón [2.21 1.9  0.43] pertence a la clase w0
# ****************************************************************************************************
# q= 0.5,	El patrón [-0.5   1.17  6.19] pertence a la clase w0
# q= 1,	El patrón [-0.5   1.17  6.19] pertence a la clase w0
# q= 2,	El patrón [-0.5   1.17  6.19] pertence a la clase w0
# q= inf,	El patrón [-0.5   1.17  6.19] pertence a la clase w0
# ****************************************************************************************************
# q= 0.5,	El patrón [0.01 1.34 2.6 ] pertence a la clase w1
# q= 1,	El patrón [0.01 1.34 2.6 ] pertence a la clase w2
# q= 2,	El patrón [0.01 1.34 2.6 ] pertence a la clase w2
# q= inf,	El patrón [0.01 1.34 2.6 ] pertence a la clase w0
# ...

# %% [markdown]
# ### Pruebas

# %%
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
X_CIRCLE,outcome = make_circles(n_samples=1000,factor=.3,noise=.1)
X_CIRCLE_train,X_CIRCLE_test , y_CIRLCE_train,y_CIRCLE_test = train_test_split(X_CIRCLE,outcome)

# %% [markdown]
# # Parzen window estimation

# %%
n = 100
mu, sigma = 10, 3 # mean and standard deviation
s = np.random.normal(mu, sigma, n)

# %%
def zipM(XY):
    for xs,ys in XY:
        for x in list(zip(xs,ys)):
            yield x

# %%
def L(x,u,sigma):
    value =  np.sum(list(map(lambda xk: (xk - u)**2 ,x)))
    return -(n*.5)*np.log(2*np.pi*sigma) - (1/(2*sigma))*value
#     print(value)
# L(s,y,sigma**2)
xLen = np.linspace(1, 20,10)
yLen = np.linspace(1, 20,10)
X,Y = np.meshgrid(xLen,yLen)
XY  = np.array(list(zip(X,Y)))
result=[]
for  uk,sigma in zipM(XY):
    lTheta = L(s,uk,sigma)
    result.append(lTheta)
Z = np.array(result).reshape(X.shape[0],Y.shape[0])

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')
surf = ax.plot_surface(X,Y,Z,cmap =cm.Dark2_r,linewidth=0,antialiased=True)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.colorbar(surf, shrink=0.5, aspect=20)
# Out:
# <img src="data:image/png;base64,..." width="453.3333453425658">

# %%
X_inside = np.array([[0,0,0],[0.2,0.2,0.2],[0.1, -0.1, -0.3]])

X_outside = np.array([[-1.2,0.3,-0.3],[0.8,-0.82,-0.9],[1, 0.6, -0.7],
                  [0.8,0.7,0.2],[0.7,-0.8,-0.45],[-0.3, 0.6, 0.9],
                  [0.7,-0.6,-0.8]])
X_all = np.vstack((X_inside,X_outside))
mu_vec = np.array([0,0])
cov_mat = np.array([[1,0],[0,1]])
X2D = np.random.multivariate_normal(mu_vec, cov_mat, 10000)
# X.shape

# %%
# %matplotlib inline
_,ax = plt.subplots(figsize=(7,7))
ax.scatter(X2D[:,0],X2D[:,1],color="black",alpha=.3,s=6)
ax.set_xlabel("$x_1$")
ax.set_ylabel("$x_2$")
ax.set_title("10000 samples from 2D Gaussian distribution")
# Out:
# Text(0.5, 1.0, '10000 samples from 2D Gaussian distribution')

# %%
def chebyshevDistance(xi,xj):
    diff = np.abs(xi-xj)
    return np.max(diff,axis=1)
a = chebyshevDistance(np.array([0,0,0]),X_all)

# %%
# distance
def distance0(x):
    def __distance0(xi):
        return x-xi
    return __distance0
# Chevishev distance  
def distance1(x):
    def __distance1(xi):
        diff = np.abs(x-xi)
        return (np.max(diff,axis=1)).reshape(-1,1)
    return __distance1

# Euclidean distance
def distance3(x):
    def __distance3(xi):
        return np.sqrt(np.power(x-xi,2).sum(axis=1))
    return __distance3
# d      = X.shape[1] 
# center = np.zeros(d)
# h = .1 
# n = X.shape[0]
# px_est(X,h=h,V=1),px_gaussian(X,h=h,V=1)

# %%
def windowFn(xs,unit_len=1):
    return np.invert(np.any( np.abs(xs) > (unit_len/2 ), axis=1 )).astype(int)

    
def fkn(X):
    return np.sum(windowFn(X))
#  P^
def parzenWindowEst(**kwargs):
    k  = kwargs.get('k',1)
    V  = kwargs.get('V',1)
    n  = kwargs.get('n',1)
    return (k/n*V)
    
    
def px_est(X,**kwargs):
    n = X.shape[0]
    h = kwargs.get('h',1)
    V = kwargs.get('V',1/np.sqrt(n))
    x = kwargs.get('center',np.zeros(X.shape[1]))
    k = np.sum(windowFn(distance1(x)(X)/h))
    p = parzenWindowEst(k=k,V=V,n=n)
    return p

center = np.array([0,0,0])
px_est(
    X,
    V      = 1,
    h      = 1,
)
# Out:
# 0.0

# %%
def gaussianKernel(X,**kwargs):
    center = kwargs.get('center',np.zeros(X.shape[1]))
    h      = kwargs.get('h',1)
    d      = X.shape[1]
    u      = distance3(center)(X)/h 
    exp0   = 1/(( np.sqrt(2*np.pi))**d)
    exp1   = np.exp(-.5*(u**2))
    return exp0*exp1
def px_gaussian(X,**kwargs):
    V      = kwargs.get('V',1)
    center = kwargs.get('center',np.zeros(X.shape[1]))
    n      = X.shape[0]
    h      = kwargs.get('h',1)
    _X      = gaussianKernel(X,h=h,center=center)
    return np.sum((1/V)*(_X))/n

# %%
xLen = np.linspace(-5, 5,100)
yLen = np.linspace(-5, 5,100)
X,Y = np.meshgrid(xLen,yLen)
XY  = np.array(list(zip(X,Y)))
result = []
for x in zipM(XY):
    x = np.array(x)
#     p = px_est(X2D,h=.1,V=1,center=x)
    p = px_gaussian(X2D,h=.1,V=1,center=x)
    result.append(p)
Z = np.array(result).reshape(X.shape[0],X.shape[1])
# X.shape,Y.shape,Z.shape

# %%
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')
surf = ax.plot_surface(X,Y,Z,cmap =cm.Dark2_r,linewidth=0,antialiased=True,alpha=.7)
ax.scatter(X2D[:,0],X2D[:,1],color="black")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
fig.colorbar(surf, shrink=0.5, aspect=20)
